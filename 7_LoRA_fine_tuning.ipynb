# %% [markdown]
# <a href="https://colab.research.google.com/github/hamshini1413/hamshini_gen_ai_foundation/blob/main/7_LoRA_fine_tuning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install --upgrade torchao
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 83.7 MB/s eta 0:00:00
# ...

# %%
# !pip install -q transformers peft accelerate datasets
# !pip uninstall -y torchao
# !pip install -U transformers peft accelerate bitsandbytes trl datasets
# Out:
# Found existing installation: torchao 0.17.0
# Uninstalling torchao-0.17.0:
#   Successfully uninstalled torchao-0.17.0
# ...

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
from peft import LoraConfig, get_peft_model

# Load a small model
model_name = "distilgpt2"

tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name)

# LoRA Configuration
lora_config = LoraConfig(
    r=8,
    lora_alpha=16,
    target_modules=["c_attn"],   # GPT-2 attention layer
    lora_dropout=0.1,
    bias="none",
    task_type="CAUSAL_LM"
)

# Apply LoRA
model = get_peft_model(model, lora_config)

# Show trainable parameters
model.print_trainable_parameters()
# Out:
# Loading weights:   0%|          | 0/76 [00:00<?, ?it/s]
# trainable params: 147,456 || all params: 82,060,032 || trainable%: 0.1797

# %%
text = "Artificial Intelligence"

inputs = tokenizer(text, return_tensors="pt")

outputs = model.generate(
    **inputs,
    max_new_tokens=20
)

print(tokenizer.decode(outputs[0], skip_special_tokens=True))
# Out:
# Artificial Intelligence (AI) is a technology that is used to create artificial intelligence (AI) that can be used

# %%
model.save_pretrained("lora_adapter")

print("LoRA Adapter Saved Successfully!")
# Out:
# LoRA Adapter Saved Successfully!
